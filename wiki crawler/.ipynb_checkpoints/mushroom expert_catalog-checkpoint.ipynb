# %%
import json
import csv
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.1

# %%
catalog = pd.read_pickle('./catalog.pkl')

# %%
# print(catalog.paragraphs[0])

catalog
# Out:
#                          link_key             key  \
# 0     polypores_stemmed_pale.html     Abortiporus
# 1                   agaricus.html        Agaricus
# 2                   agaricus.html        Agaricus
# 3                   agaricus.html        Agaricus
# 4                   agaricus.html        Agaricus
# ...                           ...             ...
# 1442                 xylaria.html         Xylaria
# 1443                 xylaria.html         Xylaria
# 1444                          NaN             NaN
# 1445                    yard.html  Yard Mushrooms
# 1446                          NaN             NaN
#
#                            link_item              item link_similar similar  \
# 0           abortiporus_biennis.html        A. biennis          NaN     NaN
# 1        agaricus_abruptibulbus.html  A. abruptibulbus          NaN     NaN
# 2             agaricus_amicosus.html       A. amicosus          NaN     NaN
# 3             agaricus_andrewii.html       A. andrewii          NaN     NaN
# 4            agaricus_argenteus.html      A. argenteus          NaN     NaN
# ...                              ...               ...          ...     ...
# 1442          xylaria_magnoliae.html      X. magnoliae          NaN     NaN
# 1443         xylaria_polymorpha.html     X. polymorpha          NaN     NaN
# 1444      xylobolus_frustulatus.html    X. frustulatus          NaN     NaN
# 1445                             NaN               NaN          NaN     NaN
# 1446  zelleromyces_cinnabarinus.html   Z. cinnabarinus          NaN     NaN
#
#                                              paragraphs  \
# 0     \nAbortiporus biennis\n[ Basidiomycota > Polyp...
# 1     \nAgaricus abruptibulbus\n[ Basidiomycota > Ag...
# 2     \nAgaricus amicosus\n[ Basidiomycota > Agarica...
# 3     \nAgaricus andrewii\n[ Basidiomycota > Agarica...
# 4     \nAgaricus argenteus\n[ Basidiomycota > Agaric...
# ...                                                 ...
# 1442  \nXylaria magnoliae\n[ Ascomycota > Sordariomy...
# 1443  \nXylaria polymorpha\n[ Ascomycota > Sordariom...
# 1444  \nXylobolus frustulatus\n[ Basidiomycetes > Ru...
# 1445
# 1446  \nZelleromyces cinnabarinus\n[ Basidiomycota >...
#
#                                                  images
# 0     images/inside_top.gif,images/kuo2/abortiporus_...
# 1     images/inside_top.gif,images/kuo6/agaricus_abr...
# 2     images/inside_top.gif,images/kuo6/agaricus_ami...
# 3     images/inside_top.gif,images/kuo6/agaricus_and...
# 4     images/inside_top.gif,images/kuo6/agaricus_arg...
# ...                                                 ...
# 1442  images/inside_top.gif,images/kuo3/xylaria_magn...
# 1443  images/inside_top.gif,images/kuo2/xylaria_poly...
# 1444  images/inside_top.gif,images/kuo2/xylobolus_fr...
# 1445
# 1446  images/inside_top.gif,images/kerner/kerner_zel...
#
# [1447 rows x 8 columns]

# %%
from selenium import webdriver
import sys


search_string = "Agaricus_bisporus wikipedia"
browser = webdriver.Chrome('chromedriver')

matched_elem = browser.get("https://www.google.com/search?q=" + search_string + "&start=" + search_string)
